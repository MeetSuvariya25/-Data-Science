# %%
pip install selenium
# Out:
# Collecting selenium
#   Using cached https://files.pythonhosted.org/packages/80/d6/4294f0b4bce4de0abf13e17190289f9d0613b0a44e5dd6a7f5ca98459853/selenium-3.141.0-py2.py3-none-any.whl
# Requirement already satisfied: urllib3 in c:\programdata\anaconda3\lib\site-packages (from selenium) (1.24.2)
# Installing collected packages: selenium
# Successfully installed selenium-3.141.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\programdata\anaconda3\lib\site-packages (4.8.0)
# Requirement already satisfied: soupsieve>=1.2 in c:\programdata\anaconda3\lib\site-packages (from beautifulsoup4) (1.9.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd

# %%
driver = webdriver.Chrome("C:/Users/HP/Downloads/chromedriver")

# %%
products=[] #List to store name of the product
prices=[] #List to store price of the product
ratings=[] #List to store rating of the product
spacification = [] #List to store spacifications of the product

driver.get("https://www.flipkart.com/laptops/pr?sid=6bo%2Cb5g&marketplace=FLIPKART&p%5B%5D=facets.price_range.from%3D40000&p%5B%5D=facets.price_range.to%3DMax")

# %%
content = driver.page_source
soup = BeautifulSoup(content)

for element in soup.findAll('div', attrs={'class':'_1AtVbE col-12-12'}):
    name=element.find('div', attrs={'class':'_4rR01T'})
    price=element.find('div', attrs={'class':'_30jeq3 _1_WHN1'})
    rating=element.find('div', attrs={'class':'_3LWZlK'})
    spacifications = element.find('div',attrs={'class':'fMghEO'})
    try:
        products.append(name.text)
        prices.append(price.text)
        ratings.append(rating.text)
        spacification.append(spacifications.text)
    except:
        continue

# %%
df = pd.DataFrame({'Product Name':products,'Price':prices,'Rating':ratings,'Spacifactions':spacification}) 
df.to_csv('products.csv', index=False, encoding='utf-8')

# %%
df.head()
# Out:
#                                         Product Name    Price Rating  \
# 0  acer Aspire 7 Ryzen 5 Quad Core 3550H - (8 GB/...  ₹51,990    4.4
# 1  Lenovo Ideapad Slim 5i Core i5 11th Gen - (8 G...  ₹63,990    4.1
# 2  HP 15s Core i3 10th Gen - (8 GB/1 TB HDD/256 G...  ₹44,490    4.3
# 3  ASUS TUF Gaming F15 Core i5 10th Gen - (8 GB/5...  ₹61,990    4.5
# 4  ASUS VivoBook 15 Core i5 10th Gen - (8 GB/1 TB...  ₹50,990    4.3
#
#                                        Spacifactions
# 0  AMD Ryzen 5 Quad Core Processor8 GB DDR4 RAM64...
# 1  Intel Core i5 Processor (11th Gen)8 GB DDR4 RA...
# 2  Intel Core i3 Processor (10th Gen)8 GB DDR4 RA...
# 3  Intel Core i5 Processor (10th Gen)8 GB DDR4 RA...
# 4  Intel Core i5 Processor (10th Gen)8 GB DDR4 RA...

# %%
df.head(20)
# Out:
#                                          Product Name    Price Rating  \
# 0   acer Aspire 7 Ryzen 5 Quad Core 3550H - (8 GB/...  ₹51,990    4.4
# 1   Lenovo Ideapad Slim 5i Core i5 11th Gen - (8 G...  ₹63,990    4.1
# 2   HP 15s Core i3 10th Gen - (8 GB/1 TB HDD/256 G...  ₹44,490    4.3
# 3   ASUS TUF Gaming F15 Core i5 10th Gen - (8 GB/5...  ₹61,990    4.5
# 4   ASUS VivoBook 15 Core i5 10th Gen - (8 GB/1 TB...  ₹50,990    4.3
# 5   MSI Modern 14 Core i3 11th Gen - (8 GB/512 GB ...  ₹46,990    4.5
# 6   HP Core i3 11th Gen - (8 GB/256 GB SSD/Windows...  ₹41,490    4.3
# 7   LG Gram 15 Core i5 10th Gen - (8 GB/256 GB SSD...  ₹72,990    4.7
# 8   DELL Inspiron 3501 Core i5 11th Gen - (8 GB/1 ...  ₹57,150    4.3
# 9   APPLE MacBook Air M1 - (8 GB/256 GB SSD/Mac OS...  ₹92,900    4.7
# 10  ASUS VivoBook Flip Ryzen 5 Hexa Core - (8 GB/5...  ₹59,990    4.6
# 11  MSI Modern 14 Ryzen 5 Hexa Core 4500U - (8 GB/...  ₹51,990    4.5
# 12  DELL Inspiron Ryzen 5 Quad Core 3450U - (8 GB/...  ₹41,690    4.1
# 13  MSI GF65 Thin Hexa Core i5 10th Gen - (16 GB/5...  ₹74,990    4.5
# 14  MSI GF63 Thin Hexa Core i5 10th Gen - (8 GB/1 ...  ₹58,990    4.5
# 15  Lenovo Ideapad Slim 3i (2021) Core i5 11th Gen...  ₹57,990    4.1
# 16  HP 14s Core i3 11th Gen - (8 GB/512 GB SSD/Win...  ₹47,990    4.3
# 17  Lenovo Ideapad Slim 5 Ryzen 7 Octa Core 5700U ...  ₹67,990    4.4
# 18  DELL Inspiron Ryzen 5 Hexa Core 5500U - (8 GB/...  ₹58,522    4.8
# 19  acer Aspire 7 Core i5 10th Gen - (8 GB/512 GB ...  ₹59,990    4.5
#
#                                         Spacifactions
# 0   AMD Ryzen 5 Quad Core Processor8 GB DDR4 RAM64...
# 1   Intel Core i5 Processor (11th Gen)8 GB DDR4 RA...
# 2   Intel Core i3 Processor (10th Gen)8 GB DDR4 RA...
# 3   Intel Core i5 Processor (10th Gen)8 GB DDR4 RA...
# 4   Intel Core i5 Processor (10th Gen)8 GB DDR4 RA...
# 5   Intel Core i3 Processor (11th Gen)8 GB DDR4 RA...
# 6   Intel Core i3 Processor (11th Gen)8 GB DDR4 RA...
# 7   Intel Core i5 Processor (10th Gen)8 GB DDR4 RA...
# 8   Intel Core i5 Processor (11th Gen)8 GB DDR4 RA...
# 9   Apple M1 Processor8 GB DDR4 RAMMac OS Operatin...
# 10  AMD Ryzen 5 Hexa Core Processor8 GB DDR4 RAM64...
# 11  AMD Ryzen 5 Hexa Core Processor8 GB DDR4 RAM64...
# 12  AMD Ryzen 5 Quad Core Processor8 GB DDR4 RAM64...
# 13  Intel Hexa Core i5 Processor (10th Gen)16 GB D...
# 14  Intel Hexa Core i5 Processor (10th Gen)8 GB DD...
# 15  Intel Core i5 Processor (11th Gen)8 GB DDR4 RA...
# 16  Intel Core i3 Processor (11th Gen)8 GB DDR4 RA...
# 17  AMD Ryzen 7 Octa Core Processor16 GB DDR4 RAM6...
# 18  AMD Ryzen 5 Hexa Core Processor8 GB DDR4 RAM64...
# 19  Intel Core i5 Processor (10th Gen)8 GB DDR4 RA...
